# %%
import pandas as pd
import maidenhead as mh
import numpy as np
import os
from datetime import datetime
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

BRAINS_CSV = '/usr/datalake/silver/stormevents/artifacts/igra_storm_event_autoencoder/brains_station_list.csv'
SEVERE_CSV = '/usr/datalake/silver/stormevents/csvfiles/severe_maidenhead.csv'
IGRA_CSV_PATTERN = '/usr/datalake/silver/stormevents/igra_encoded/{station_id}_igra_encoded.csv'
IGRA_MAIDENHEAD_PATH = '/usr/datalake/silver/stormevents/csvfiles/igra_maidenhead'
MAIDENHEADS = ['DN', 'EN', 'FN', 'DM', 'EM', 'FM', 'DL', 'EL']

# %%
os.makedirs(IGRA_MAIDENHEAD_PATH, exist_ok=True)

# %%
class OlieStormEvents:
    start_date = datetime(1990, 1, 1)
    stop_date = datetime(2025, 5, 30)

    def __init__(self, severe_path: str):
        self.storm_events = pd.read_csv(severe_path)

    def get_storm_events(self, maidenhead: str) -> pd.DataFrame:
        result = self._get_filtered(maidenhead)
        result = self._merge_temporal(result)

        return result

    def _get_filtered(self, maidenhead: str) -> pd.DataFrame:
        result = self.storm_events.copy()
        result = result[result['MAIDENHEAD'] == maidenhead]
        result['EFFECTIVE'] = pd.to_datetime(result['EFFECTIVE'])
        result = result.drop(labels=['MAIDENHEAD'], axis=1)

        return result
    
    def _merge_temporal(self, df_source: pd.DataFrame):
        result = pd.DataFrame(pd.date_range(self.start_date, self.stop_date), columns=['effective'])
        result = result.merge(df_source, how='left', left_on=['effective'], right_on=['EFFECTIVE'])
        result = result.drop(labels=['EFFECTIVE'], axis=1)
        result = result.fillna(0)
        result['LABEL'] = result['LABEL'].astype(int)

        return result

class OlieIgra:
    def __init__(self, stations_path: str):
        self.stations = pd.read_csv(stations_path)

    def get_igra(self, maidenhead: str, limit: int):
        ids = self._get_closest_stations(maidenhead, limit)
        result = self._merge_closest_igras(ids)

        return result

    def _get_closest_stations(self, maidenhead: str, limit: int) -> list[str]:
        lat, lon = mh.to_location(maidenhead, True)
        result = self.stations.copy()
        result['distance'] = result.apply(lambda x: self._haversine_distance(x.latitude, x.longitude, lat, lon), axis=1)
        result = result.sort_values(by='distance')
        result = result.iloc[0:limit]

        ids = result['id'].to_numpy()

        return ids

    def _merge_closest_igras(self, station_ids: list[str]) -> pd.DataFrame:
        df_igra = [self._read_igra_by_id(station_ids[i]) for i in range(3)]

        result = pd.merge(left=df_igra[0], right=df_igra[1], how="inner", left_on='effective_date', right_on='effective_date')
        result = pd.merge(left=result, right=df_igra[2], how="inner", left_on='effective_date', right_on='effective_date')
        result = result.drop(labels=['day_num', 'day_num_y'], axis=1)
        result.columns = self._get_column_names()

        return result
    
    @staticmethod
    def _haversine_distance(lat1: float, lon1: float, lat2: float, lon2: float, earth_radius=6371.0): # Earth radius in km
        lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

        dlat = lat2 - lat1
        dlon = lon2 - lon1

        a = np.sin(dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2
        c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

        distance = earth_radius * c
        return distance
    
    @staticmethod
    def _read_igra_by_id(station_id: str) -> pd.DataFrame:
        filename = IGRA_CSV_PATTERN.replace('{station_id}', station_id)
        result = pd.read_csv(filename)
        result['effective_date'] = pd.to_datetime(result['effective_date'])

        return result
    
    @staticmethod
    def _get_column_names():
        result = [f'{i}' for i in range(-1, 61)]
        result[0] = 'effective_date'
        result = np.array(result)

        return result
    
class OlieMaidenhead:
    def get_maidenheads(self, fields: list[str]) -> list[str]:
        result = []

        for key in fields:
            for row in range(10):
                for col in range(10):
                    maidenhead = f'{key}{row}{col}'
                    result.append(maidenhead)

        return result
    
    def merge_severe_igra(self, features: pd.DataFrame, labels: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame, int]:
        merged = features.merge(labels, how='inner', left_on=['effective_date'], right_on=['effective'])
        merged = merged.drop(labels=['effective', 'effective_date'], axis=1)
        feature_result = merged.iloc[:,:-1]
        label_result = merged.iloc[:,-1:]
        severe = label_result[label_result['LABEL'] > 0]
        significant = label_result[label_result['LABEL'] > 1]

        return feature_result, label_result, severe.shape[0], significant.shape[0]
    
    def undersample_non_severe(self, x: pd.DataFrame, y: pd.DataFrame, threshold: int) -> tuple[pd.DataFrame, pd.DataFrame]:
        n_count = y['LABEL'].value_counts().to_dict()
        if n_count[0] <= threshold:
            return x, y
        n_count[0] = threshold

        rus = RandomUnderSampler(sampling_strategy=n_count)
        r_x, r_y = rus.fit_resample(x, y)

        return r_x, r_y

    def oversample_severe(self, x: pd.DataFrame, y: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
        rus = SMOTE()
        r_x, r_y = rus.fit_resample(x, y)

        return r_x, r_y

# %%
# df_merged.to_csv(f'{IGRA_MAIDENHEAD_PATH}/{MAIDENHEAD}.csv', index=False)

# %%
olie_storm_events = OlieStormEvents(SEVERE_CSV)
olie_igra = OlieIgra(BRAINS_CSV)
olie_maidenhead = OlieMaidenhead()

for maidenhead in olie_maidenhead.get_maidenheads(MAIDENHEADS):
    storm_events = olie_storm_events.get_storm_events(maidenhead)
    igras = olie_igra.get_igra(maidenhead, 3)
    df_features, df_labels, severe_count, significant_count = olie_maidenhead.merge_severe_igra(igras, storm_events)

    if severe_count == 0:
        print (f'Maidenhead {maidenhead}: No severe records')
        continue

    if severe_count < 100:
        print (f'Maidenhead {maidenhead}: Not enough severe records')
        continue

    if significant_count < 6:
        # SMOTE requires at lest 6 samples
        df_labels.loc[df_labels['LABEL'] > 1, 'LABEL'] = 1
        significant_count = 0

    df_features, df_labels = olie_maidenhead.undersample_non_severe(df_features, df_labels, severe_count * 10)
    df_balanced_features, df_balanced_labels = olie_maidenhead.oversample_severe(df_features, df_labels)
    
    df_merged = pd.concat([df_balanced_features, df_balanced_labels], axis=1)
    df_merged.to_csv(f'{IGRA_MAIDENHEAD_PATH}/{maidenhead}.csv', index=False)
    
    print (f'Maidenhead {maidenhead}: {df_merged.shape}')
# Out:
# Maidenhead DN00: Not enough severe records
# Maidenhead DN01: Not enough severe records
# Maidenhead DN02: Not enough severe records
# Maidenhead DN03: Not enough severe records
# Maidenhead DN04: Not enough severe records
# Maidenhead DN05: Not enough severe records
# Maidenhead DN06: Not enough severe records
# Maidenhead DN07: Not enough severe records
# Maidenhead DN08: Not enough severe records
# Maidenhead DN09: Not enough severe records
# Maidenhead DN10: Not enough severe records
# Maidenhead DN11: Not enough severe records
# Maidenhead DN12: Not enough severe records
# Maidenhead DN13: Not enough severe records
# Maidenhead DN14: Not enough severe records
# Maidenhead DN15: Not enough severe records
# Maidenhead DN16: Not enough severe records
# Maidenhead DN17: Not enough severe records
# Maidenhead DN18: Not enough severe records
# Maidenhead DN19: No severe records
# Maidenhead DN20: Not enough severe records
# Maidenhead DN21: Not enough severe records
# Maidenhead DN22: Not enough severe records
# Maidenhead DN23: Not enough severe records
# Maidenhead DN24: Not enough severe records
# Maidenhead DN25: Not enough severe records
# Maidenhead DN26: Not enough severe records
# Maidenhead DN27: Not enough severe records
# Maidenhead DN28: Not enough severe records
# Maidenhead DN29: No severe records
# Maidenhead DN30: (3260, 62)
# Maidenhead DN31: Not enough severe records
# Maidenhead DN32: (2260, 62)
# Maidenhead DN33: (2540, 62)
# Maidenhead DN34: Not enough severe records
# Maidenhead DN35: Not enough severe records
# Maidenhead DN36: (2000, 62)
# Maidenhead DN37: Not enough severe records
# Maidenhead DN38: Not enough severe records
# Maidenhead DN39: No severe records
# Maidenhead DN40: (2660, 62)
# Maidenhead DN41: Not enough severe records
# Maidenhead DN42: Not enough severe records
# Maidenhead DN43: Not enough severe records
# Maidenhead DN44: Not enough severe records
# Maidenhead DN45: (2360, 62)
# Maidenhead DN46: Not enough severe records
# Maidenhead DN47: (4680, 62)
# Maidenhead DN48: Not enough severe records
# Maidenhead DN49: Not enough severe records
# Maidenhead DN50: Not enough severe records
# Maidenhead DN51: Not enough severe records
# Maidenhead DN52: Not enough severe records
# Maidenhead DN53: Not enough severe records
# Maidenhead DN54: Not enough severe records
# Maidenhead DN55: (5970, 62)
# Maidenhead DN56: (3930, 62)
# Maidenhead DN57: (3960, 62)
# Maidenhead DN58: Not enough severe records
# Maidenhead DN59: Not enough severe records
# Maidenhead DN60: Not enough severe records
# Maidenhead DN61: Not enough severe records
# Maidenhead DN62: Not enough severe records
# Maidenhead DN63: Not enough severe records
# Maidenhead DN64: (4140, 62)
# Maidenhead DN65: (4080, 62)
# Maidenhead DN66: (3600, 62)
# Maidenhead DN67: (4440, 62)
# Maidenhead DN68: (4560, 62)
# Maidenhead DN69: Not enough severe records
# Maidenhead DN70: (8310, 62)
# Maidenhead DN71: (9810, 62)
# Maidenhead DN72: (6540, 62)
# Maidenhead DN73: (6450, 62)
# Maidenhead DN74: (9480, 62)
# Maidenhead DN75: (5610, 62)
# Maidenhead DN76: (4800, 62)
# Maidenhead DN77: (4950, 62)
# Maidenhead DN78: (4200, 62)
# Maidenhead DN79: Not enough severe records
# Maidenhead DN80: (14520, 62)
# Maidenhead DN81: (12900, 62)
# Maidenhead DN82: (9660, 62)
# Maidenhead DN83: (13260, 62)
# Maidenhead DN84: (12810, 62)
# Maidenhead DN85: (7590, 62)
# Maidenhead DN86: (6330, 62)
# Maidenhead DN87: (4050, 62)
# Maidenhead DN88: (3150, 62)
# Maidenhead DN89: Not enough severe records
# Maidenhead DN90: (12780, 62)
# Maidenhead DN91: (11970, 62)
# Maidenhead DN92: (9030, 62)
# Maidenhead DN93: (8940, 62)
# Maidenhead DN94: (7350, 62)
# Maidenhead DN95: (5550, 62)
# Maidenhead DN96: (5970, 62)
# Maidenhead DN97: (4230, 62)
# Maidenhead DN98: (3990, 62)
# Maidenhead DN99: Not enough severe records
# Maidenhead EN00: (9570, 62)
# Maidenhead EN01: (8340, 62)
# Maidenhead EN02: (7140, 62)
# Maidenhead EN03: (6720, 62)
# Maidenhead EN04: (5400, 62)
# Maidenhead EN05: (5850, 62)
# Maidenhead EN06: (4710, 62)
# Maidenhead EN07: (4410, 62)
# Maidenhead EN08: (4170, 62)
# Maidenhead EN09: Not enough severe records
# Maidenhead EN10: (8880, 62)
# Maidenhead EN11: (8370, 62)
# Maidenhead EN12: (7320, 62)
# Maidenhead EN13: (6660, 62)
# Maidenhead EN14: (5580, 62)
# Maidenhead EN15: (4950, 62)
# Maidenhead EN16: (5670, 62)
# Maidenhead EN17: (5220, 62)
# Maidenhead EN18: (4650, 62)
# Maidenhead EN19: Not enough severe records
# Maidenhead EN20: (6720, 62)
# Maidenhead EN21: (7710, 62)
# Maidenhead EN22: (6630, 62)
# Maidenhead EN23: (6510, 62)
# Maidenhead EN24: (6330, 62)
# Maidenhead EN25: (5550, 62)
# Maidenhead EN26: (4800, 62)
# Maidenhead EN27: (3900, 62)
# Maidenhead EN28: Not enough severe records
# Maidenhead EN29: Not enough severe records
# Maidenhead EN30: (6480, 62)
# Maidenhead EN31: (7710, 62)
# Maidenhead EN32: (6720, 62)
# Maidenhead EN33: (6720, 62)
# Maidenhead EN34: (7140, 62)
# Maidenhead EN35: (6120, 62)
# Maidenhead EN36: (3870, 62)
# Maidenhead EN37: Not enough severe records
# Maidenhead EN38: Not enough severe records
# Maidenhead EN39: Not enough severe records
# Maidenhead EN40: (8310, 62)
# Maidenhead EN41: (7860, 62)
# Maidenhead EN42: (6570, 62)
# Maidenhead EN43: (5460, 62)
# Maidenhead EN44: (5280, 62)
# Maidenhead EN45: (4200, 62)
# Maidenhead EN46: Not enough severe records
# Maidenhead EN47: Not enough severe records
# Maidenhead EN48: Not enough severe records
# Maidenhead EN49: No severe records
# Maidenhead EN50: (8550, 62)
# Maidenhead EN51: (8550, 62)
# Maidenhead EN52: (8580, 62)
# Maidenhead EN53: (7800, 62)
# Maidenhead EN54: (6450, 62)
# Maidenhead EN55: (4890, 62)
# Maidenhead EN56: Not enough severe records
# Maidenhead EN57: Not enough severe records
# Maidenhead EN58: Not enough severe records
# Maidenhead EN59: No severe records
# Maidenhead EN60: (8940, 62)
# Maidenhead EN61: (9450, 62)
# Maidenhead EN62: (4440, 62)
# Maidenhead EN63: Not enough severe records
# Maidenhead EN64: Not enough severe records
# Maidenhead EN65: (3210, 62)
# Maidenhead EN66: Not enough severe records
# Maidenhead EN67: No severe records
# Maidenhead EN68: No severe records
# Maidenhead EN69: No severe records
# Maidenhead EN70: (9900, 62)
# Maidenhead EN71: (9210, 62)
# Maidenhead EN72: (6690, 62)
# Maidenhead DM51: Not enough severe records
# Maidenhead DM52: (2200, 62)
# Maidenhead DM53: Not enough severe records
# Maidenhead DM54: Not enough severe records
# Maidenhead DM55: Not enough severe records
# Maidenhead DM56: Not enough severe records
# Maidenhead DM57: Not enough severe records
# Maidenhead DM58: Not enough severe records
# Maidenhead DM59: Not enough severe records
# Maidenhead DM60: No severe records
# Maidenhead DM61: Not enough severe records
# Maidenhead DM62: Not enough severe records
# Maidenhead DM63: Not enough severe records
# Maidenhead DM64: Not enough severe records
# Maidenhead DM65: (2760, 62)
# Maidenhead DM66: Not enough severe records
# Maidenhead DM67: Not enough severe records
# Maidenhead DM68: Not enough severe records
# Maidenhead DM69: Not enough severe records
# Maidenhead DM70: Not enough severe records
# Maidenhead DM71: Not enough severe records
# Maidenhead DM72: (4740, 62)
# Maidenhead DM73: (3600, 62)
# Maidenhead DM74: (3870, 62)
# Maidenhead DM75: (5010, 62)
# Maidenhead DM76: (4020, 62)
# Maidenhead DM77: (3570, 62)
# Maidenhead DM78: (10800, 62)
# Maidenhead DM79: (12480, 62)
# Maidenhead DM80: (6810, 62)
# Maidenhead DM81: (7950, 62)
# Maidenhead DM82: (7590, 62)
# Maidenhead DM83: (7380, 62)
# Maidenhead DM84: (9750, 62)
# Maidenhead DM85: (8430, 62)
# Maidenhead DM86: (8550, 62)
# Maidenhead DM87: (7170, 62)
# Maidenhead DM88: (12870, 62)
# Maidenhead DM89: (14760, 62)
# Maidenhead DM90: (3120, 62)
# Maidenhead DM91: (6660, 62)
# Maidenhead DM92: (8940, 62)
# Maidenhead DM93: (10680, 62)
# Maidenhead DM94: (10140, 62)
# Maidenhead DM95: (12600, 62)
# Maidenhead DM96: (9840, 62)
# Maidenhead DM97: (15060, 62)
# Maidenhead DM98: (14220, 62)
# Maidenhead DM99: (17070, 62)
# Maidenhead EM00: (5850, 62)
# Maidenhead EM01: (7110, 62)
# Maidenhead EM02: (8460, 62)
# Maidenhead EM03: (7650, 62)
# Maidenhead EM04: (9840, 62)
# Maidenhead EM05: (9420, 62)
# Maidenhead EM06: (8820, 62)
# Maidenhead EM07: (12210, 62)
# Maidenhead EM08: (11670, 62)
# Maidenhead EM09: (10050, 62)
# Maidenhead EM10: (7920, 62)
# Maidenhead EM11: (6990, 62)
# Maidenhead EM12: (10530, 62)
# Maidenhead EM13: (10200, 62)
# Maidenhead EM14: (8760, 62)
# Maidenhead EM15: (10410, 62)
# Maidenhead EM16: (8820, 62)
# Maidenhead EM17: (9510, 62)
# Maidenhead EM18: (9390, 62)
# Maidenhead EM19: (9450, 62)
# Maidenhead EM20: (8070, 62)
# Maidenhead EM21: (8430, 62)
# Maidenhead EM22: (9930, 62)
# Maidenhead EM23: (7980, 62)
# Maidenhead EM24: (8130, 62)
# Maidenhead EM25: (8280, 62)
# Maidenhead EM26: (9330, 62)
# Maidenhead EM27: (7890, 62)
# Maidenhead EM28: (8640, 62)
# Maidenhead EM29: (8760, 62)
# Maidenhead EM30: (8190, 62)
# Maidenhead EM31: (8550, 62)
# Maidenhead EM32: (10140, 62)
# Maidenhead EM33: (8580, 62)
# Maidenhead EM34: (10620, 62)
# Maidenhead EM35: (9210, 62)
# Maidenhead EM36: (9330, 62)
# Maidenhead EM37: (8700, 62)
# Maidenhead EM38: (8250, 62)
# Maidenhead EM39: (6060, 62)
# Maidenhead EM40: (9570, 62)
# Maidenhead EM41: (11610, 62)
# Maidenhead EM42: (14010, 62)
# Maidenhead EM43: (8400, 62)
# Maidenhead EM44: (6060, 62)
# Maidenhead EM45: (7590, 62)
# Maidenhead EM46: (7770, 62)
# Maidenhead EM47: (6960, 62)
# Maidenhead EM48: (10260, 62)
# Maidenhead EM49: (7650, 62)
# Maidenhead EM50: (8340, 62)
# Maidenhead EM51: (14130, 62)
# Maidenhead EM52: (13890, 62)
# Maidenhead EM53: (10290, 62)
# Maidenhead EM54: (9120, 62)
# Maidenhead EM55: (8250, 62)
# Maidenhead EM56: (8070, 62)
# Maidenhead EM57: (9960, 62)
# Maidenhead EM58: (9660, 62)
# Maidenhead EM59: (9510, 62)
# Maidenhead EM60: (4040, 62)
# Maidenhead EM61: (8040, 62)
# Maidenhead EM62: (7770, 62)
# Maidenhead EM63: (11970, 62)
# Maidenhead EM64: (14910, 62)
# Maidenhead EM65: (12360, 62)
# Maidenhead EM66: (13200, 62)
# Maidenhead EM67: (9090, 62)
# Maidenhead EM68: (9240, 62)
# Maidenhead EM69: (9960, 62)
# Maidenhead EM70: (6860, 62)
# Maidenhead EM71: (10980, 62)
# Maidenhead EM72: (11220, 62)
# Maidenhead EM73: (16830, 62)
# Maidenhead EM74: (16500, 62)
# Maidenhead EM75: (13740, 62)
# Maidenhead EM76: (11760, 62)
# Maidenhead EM77: (11400, 62)
# Maidenhead EM78: (11610, 62)
# Maidenhead EM79: (12120, 62)
# Maidenhead EM80: (12720, 62)
# Maidenhead EM81: (11520, 62)
# Maidenhead EM82: (12510, 62)
# Maidenhead EM83: (11880, 62)
# Maidenhead EM84: (16140, 62)
# Maidenhead EM85: (15600, 62)
# Maidenhead EM86: (12930, 62)
# Maidenhead EM87: (10710, 62)
# Maidenhead EM88: (10800, 62)
# Maidenhead EM89: (12300, 62)
# Maidenhead EM90: (10800, 62)
# Maidenhead EM91: (8340, 62)
# Maidenhead EM92: (15420, 62)
# Maidenhead EM93: (15600, 62)
# Maidenhead EM94: (16770, 62)
# Maidenhead EM95: (18468, 62)
# Maidenhead EM96: (14370, 62)
# Maidenhead EM97: (10770, 62)
# Maidenhead EM98: (7980, 62)
# Maidenhead EM99: (9780, 62)
# Maidenhead FM00: No severe records
# Maidenhead FM01: No severe records
# Maidenhead FM02: Not enough severe records
# Maidenhead FM03: (7050, 62)
# Maidenhead FM04: (12750, 62)
# Maidenhead FM05: (15510, 62)
# Maidenhead FM06: (16410, 62)
# Maidenhead FM07: (14490, 62)
# Maidenhead FM08: (7920, 62)
# Maidenhead FM09: (10170, 62)
# Maidenhead FM10: No severe records
# Maidenhead FM11: No severe records
# Maidenhead FM12: No severe records
# Maidenhead FM13: Not enough severe records
# Maidenhead FM14: (5700, 62)
# Maidenhead FM15: (5370, 62)
