# %%
import os
import pandas as pd
import glob

# %%
BRONZE_PATH = '/usr/datalake/bronze/stormevents/csvfiles'
SILVER_PATH = '/usr/datalake/silver/stormevents/csvfiles'
PATTERN = 'StormEvents_details-ftp_v1.0_d*.csv.gz'

os.makedirs(SILVER_PATH, exist_ok=True)

# %%
search = f'{BRONZE_PATH}/{PATTERN}'

for filename in glob.glob(search):
    df = pd.read_csv(filename)

    silver = f'{SILVER_PATH}/{filename.replace("\\","/").split("/")[-1]}'[:-3]
    if os.path.exists(silver):
        print(f"Skipping {silver} because it already exists")

    df.to_csv(silver, index=False)
    print(f"Transformed {silver}")
# Out:
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2000_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2001_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2002_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2003_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2004_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2005_c20250520.csv
# C:\Users\oliev\AppData\Local\Temp\ipykernel_1456\3935159.py:4: DtypeWarning: Columns (29,34,35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2006_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2007_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2008_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2009_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2010_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2011_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2012_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2013_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2014_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2015_c20250818.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2016_c20250818.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2017_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2018_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2019_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2020_c20250702.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2021_c20250520.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2022_c20250721.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2023_c20250731.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2024_c20250818.csv
# Transformed /usr/datalake/silver/stormevents/csvfiles/StormEvents_details-ftp_v1.0_d2025_c20250818.csv
