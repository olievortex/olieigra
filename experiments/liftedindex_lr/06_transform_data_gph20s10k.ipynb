# %% [markdown]
# # Transform Data gph20s10k
# Transform the data-por observations into a format we can use for machine learning. The problem is the samples in an observation are not consistent between observations. The solution is to interpolate data into standardized levels. We split the samples into 20 levels between the surface and 10km. This allows all the observations to be consistent for a given station. Although the number of levels are the same between other stations, because the surface elevation is different, the actual altitudes of each slice will be different.
#
# Observations are also filtered on quality. If there are less than 20 samples without data problems between the surface and 10km geopotential height, the entire observation is rejected. If a surface sample has any invalid data, the entire observation is also rejected.
#
# Update the following parameters in the first cell to accomodate your installation:
#
# - BRONZE_DATA_POR_PATH - The location of the raw data-por zip files
# - SILVER_GPH20S10K_PATH - The location to save the transformed CSV files

# %%
# If you need to install olieigra, uncomment and execute this line. View the README in the project root for instructions
# on how to build or download this file.
#%pip install /lakehouse/default/Files/libs/olieigra-0.0.1-py3-none-any.whl

# %%
import math
import os
from datetime import datetime
import numpy as np
import olieigra

BRONZE_DATA_POR_PATH = '/usr/datalake/bronze/igra/data-por'
SILVER_GPH20S10K_PATH = '/usr/datalake/silver/igra/gph20s10k'

# %%
# Make sure the destination path exists
os.makedirs(SILVER_GPH20S10K_PATH, exist_ok=True)

# %%
# The business logic is contained within this class

class Gph20S10K(olieigra.Callbacks):
    samples = 21
    gph_top = 10000
    min_usable = 20

    def __init__(self, dst_path: str, min_effective_date: datetime):
        super().__init__()
        self.dst_path = dst_path
        self.filename = ''
        self.filtered = 0
        self.rejected = 0
        self.writer = None
        self.min_effective_date = min_effective_date
        self.hout = ''
        self.levels = []

    def start_file(self, filename: str) -> bool:
        """Decide if we want to process the file. If so, reset state and start writing to a
        temporary file."""

        # An IGRA2 file should end with -data.txt
        if not filename.endswith('-data.txt'):
            print(f'Skipping {filename}. Not sure what to do with it.')
            return False

        # Set the desired destination filename
        dst_filename = f'{self.dst_path}/{filename}'
        dst_filename = dst_filename.replace("-data.txt", "-data-gph20s10k.csv")

        # Skip this file if it has already been processed
        if os.path.exists(dst_filename):
            print(f'Skipping {filename}. Destination file already exists.')
            return False

        # If we got here, we are going to process the file
        print(f'Processing {filename}.')

        # Write to a temp file
        self.filename = dst_filename.replace('.csv', '.partial.csv')
        self.writer = open(self.filename, 'w', encoding='UTF-8')
        self.hout = ''

        # Reset the record counts
        self.filtered = 0
        self.rejected = 0

        # Write the header row
        attr = ['gph','pres','temp','dp','u','v']
        dynamic = ','.join([f'{level}_{x}'
                            for level in range(self.samples)
                            for x in attr])
        self.writer.write(f"id,effective_date,hour,day_num,{dynamic}\n")

        # Tell olieigra to continue processing
        return True

    def finish_file(self, headers: int, rows: int):
        """Callback for when processing is complete"""

        # Flush and close the temp file
        self.writer.close()

        # Rename it to the final filename
        dst_renamed = self.filename.replace('.partial.csv', '.csv')
        os.rename(self.filename, dst_renamed)

        # Calculate the number of records written
        loaded = headers - self.filtered - self.rejected

        print(f" Read {headers} headers, {rows} lines. Filtered {self.filtered}. " +
              f"Rejected {self.rejected}. Wrote {loaded} records.")

    def parse_header(self, header: olieigra.HeaderModel):
        """Transform the header record"""

        # Combine seperate fields into a datetime
        effective_date = datetime(header.year, header.month, header.day)

        # Filter out the observations that are too old
        if effective_date < self.min_effective_date:
            self.filtered += 1
            return False

        # We need some number that is analogous to the amount of sunlight and the season
        day_num = -math.cos(math.radians(effective_date.timetuple().tm_yday))

        # The observation may be rejected due to body data issues. Save the header values to
        # a variable for now. The parse_body will write it to the file, if appropriate.
        self.hout = f'{header.id},{effective_date:%Y-%m-%d},{header.hour},{day_num:.2f}'

        # Continue the processing
        return True

    def parse_body(self, body: list[olieigra.BodyModel]):
        """Perform some analytics on the body"""

        # Remove non-pressure records and records with bad data
        filtered = self.filter_body(body)

        # If the obs failed validation checks, skip it
        if len(filtered) == 0:
            self.rejected += 1
            return

        # Have we calculated the levels yet?
        if len(self.levels) == 0:
            # We can't calculate the levels until we've had a surface sample
            self.levels = np.linspace(filtered[0][0], self.gph_top, self.samples)

        # Convert rows to columns and interpolate to our standard levels
        pivoted = self.body_pivot(filtered)

        # Combine the results to a comma delimited list
        out = ','.join([f"{item:.1f}" for item in pivoted])

        # Write the record
        self.writer.write(f'{self.hout},{out}\n')

    def filter_body(self, body: list[olieigra.BodyModel]) -> list[list[float]]:
        """Filter out bad data"""
        result = [[], [], [], [], [], []]
        usable_count = 0
        surface_nan = 1
        last_gph = -1

        # Iterate over every body record
        for item in body:
            # If we have at least one record over 10k in height, we have enough data to interpolate
            if last_gph >= 10000:
                break

            # Skip non-pressure records
            if item.type[0] == '3':
                continue

            # Skip records with bad or missing data
            if math.isnan(item.dpdp) | math.isnan(item.rh) | math.isnan(item.temp) | \
                    math.isnan(item.wdir) | math.isnan(item.wspd) | math.isnan(item.gph):
                continue

            # If we got here, the record passed validation. Add it to the results.
            result.append(self.transform_body(item, result))

            # Clear the flag if we find a valid surface sample
            if item.type == '21':
                surface_nan = 0

            # Update tracking variables
            last_gph = item.gph
            usable_count += 1

        # Final validation
        if usable_count >= self.min_usable and surface_nan == 0 and last_gph >= self.gph_top:
            # Reject the entire obs if we don't have 20 valid samples, there is 
            # not a valid surface sample, or if the balloon didn't make it to 10k
            # above the surface.
            return result
        else:
            # Passed validation, return the results
            return []

    def transform_body(self, item: olieigra.BodyModel, agg: list[list[float]]):
        """Transform the body"""

        agg[0].append(item.gph)
        agg[1].append(item.pres / 100.0)
        agg[2].append(item.temp / 10.0)
        agg[3].append((item.temp - item.dpdp) / 10.0)

        # Convert wind from degrees/m^s to u,v
        wrad = math.radians(item.wdir)
        agg[4].append(-item.wspd * math.sin(wrad) / 10.0)
        agg[5].append(-item.wspd * math.cos(wrad) / 10.0)

    def body_pivot(self, body: list[list[float]]) -> list[float]:
        """Pivot and interpolate the levels"""
        return [np.interp(level, body[0], x)
                for level in self.levels
                for x in [body[0], body[1], body[2], body[3], body[4], body[5]]]

# %%
callbacks = Gph20S10K(SILVER_GPH20S10K_PATH, datetime(1990, 1, 1))
reader = olieigra.Reader(callbacks=callbacks)
crawler = olieigra.Crawler(reader=reader)

crawler.crawl(BRONZE_DATA_POR_PATH)
# Out:
# Processing BBM00078954-data.txt.
#  Read 31862 headers, 2740891 lines. Filtered 14719. Rejected 10577. Wrote 6566 records.
# Processing BDM00078016-data.txt.
#  Read 64112 headers, 2470305 lines. Filtered 43804. Rejected 20308. Wrote 0 records.
# Processing BHM00078583-data.txt.
#  Read 21481 headers, 2080720 lines. Filtered 5245. Rejected 11208. Wrote 5028 records.
# Processing BRM00082022-data.txt.
#  Read 11629 headers, 1270423 lines. Filtered 1449. Rejected 10180. Wrote 0 records.
# Processing BRM00082026-data.txt.
#  Read 9456 headers, 1185238 lines. Filtered 0. Rejected 9456. Wrote 0 records.
# Processing BRM00082099-data.txt.
#  Read 9307 headers, 1172214 lines. Filtered 0. Rejected 9307. Wrote 0 records.
# Processing CAM00071043-data.txt.
#  Read 52060 headers, 3720156 lines. Filtered 26147. Rejected 25913. Wrote 0 records.
# Processing CAM00071081-data.txt.
#  Read 48995 headers, 3536064 lines. Filtered 23439. Rejected 25556. Wrote 0 records.
# Processing CAM00071082-data.txt.
#  Read 54750 headers, 3606141 lines. Filtered 28331. Rejected 26419. Wrote 0 records.
# Processing CAM00071109-data.txt.
#  Read 52494 headers, 3468650 lines. Filtered 26621. Rejected 25873. Wrote 0 records.
# Processing CAM00071119-data.txt.
#  Read 52500 headers, 3602890 lines. Filtered 25441. Rejected 27059. Wrote 0 records.
# Processing CAM00071603-data.txt.
#  Read 26223 headers, 2790718 lines. Filtered 724. Rejected 25499. Wrote 0 records.
# Processing CAM00071701-data.txt.
#  Read 11205 headers, 474916 lines. Filtered 4311. Rejected 6894. Wrote 0 records.
# Processing CAM00071722-data.txt.
#  Read 50269 headers, 3504493 lines. Filtered 24244. Rejected 26025. Wrote 0 records.
# Processing CAM00071802-data.txt.
#  Read 11839 headers, 1375843 lines. Filtered 0. Rejected 11839. Wrote 0 records.
# Processing CAM00071811-data.txt.
#  Read 50131 headers, 3555691 lines. Filtered 24176. Rejected 25955. Wrote 0 records.
# Processing CAM00071815-data.txt.
#  Read 66023 headers, 3682005 lines. Filtered 42565. Rejected 23458. Wrote 0 records.
# Processing CAM00071816-data.txt.
#  Read 64956 headers, 3541602 lines. Filtered 39023. Rejected 25933. Wrote 0 records.
# Processing CAM00071823-data.txt.
#  Read 28663 headers, 2790656 lines. Filtered 2887. Rejected 25776. Wrote 0 records.
# Processing CAM00071843-data.txt.
#  Read 554 headers, 39278 lines. Filtered 0. Rejected 554. Wrote 0 records.
# Processing CAM00071845-data.txt.
#  Read 23932 headers, 2610599 lines. Filtered 0. Rejected 23932. Wrote 0 records.
# Processing CAM00071867-data.txt.
#  Read 50706 headers, 3496138 lines. Filtered 24806. Rejected 25900. Wrote 0 records.
# Processing CAM00071906-data.txt.
#  Read 52583 headers, 3323446 lines. Filtered 27186. Rejected 25397. Wrote 0 records.
# Processing CAM00071907-data.txt.
#  Read 52706 headers, 3316335 lines. Filtered 28014. Rejected 24692. Wrote 0 records.
# Processing CAM00071908-data.txt.
#  Read 18932 headers, 2245048 lines. Filtered 0. Rejected 18932. Wrote 0 records.
# Processing CAM00071909-data.txt.
#  Read 55287 headers, 3363491 lines. Filtered 30315. Rejected 24972. Wrote 0 records.
# Processing CAM00071913-data.txt.
#  Read 53776 headers, 3484083 lines. Filtered 28688. Rejected 25088. Wrote 0 records.
# Processing CAM00071917-data.txt.
#  Read 57023 headers, 3742863 lines. Filtered 30039. Rejected 26984. Wrote 0 records.
# Processing CAM00071924-data.txt.
#  Read 57301 headers, 3550711 lines. Filtered 31482. Rejected 25819. Wrote 0 records.
# Processing CAM00071925-data.txt.
#  Read 40515 headers, 3589089 lines. Filtered 14657. Rejected 25858. Wrote 0 records.
# Processing CAM00071926-data.txt.
#  Read 48880 headers, 3262741 lines. Filtered 23826. Rejected 25054. Wrote 0 records.
# Processing CAM00071934-data.txt.
#  Read 48742 headers, 3208938 lines. Filtered 24190. Rejected 24552. Wrote 0 records.
# Processing CAM00071945-data.txt.
#  Read 50578 headers, 3408876 lines. Filtered 24814. Rejected 25764. Wrote 0 records.
# Processing CAM00071957-data.txt.
#  Read 47866 headers, 3696146 lines. Filtered 21467. Rejected 26399. Wrote 0 records.
# Processing CAM00071964-data.txt.
#  Read 50096 headers, 3238951 lines. Filtered 25561. Rejected 24535. Wrote 0 records.
# Processing CAM00073033-data.txt.
#  Read 21343 headers, 1309128 lines. Filtered 12881. Rejected 8462. Wrote 0 records.
# Processing CAM00073111-data.txt.
#  Read 1443 headers, 188495 lines. Filtered 0. Rejected 1443. Wrote 0 records.
# Processing CJM00078384-data.txt.
#  Read 37597 headers, 2273941 lines. Filtered 23589. Rejected 11575. Wrote 2433 records.
# Processing COM00080001-data.txt.
#  Read 27648 headers, 1433963 lines. Filtered 16751. Rejected 9951. Wrote 946 records.
# Processing COM00080028-data.txt.
#  Read 1534 headers, 225346 lines. Filtered 0. Rejected 1534. Wrote 0 records.
# Processing COM00080094-data.txt.
#  Read 1406 headers, 173268 lines. Filtered 0. Rejected 1406. Wrote 0 records.
# Processing COM00080222-data.txt.
#  Read 26293 headers, 1345382 lines. Filtered 14817. Rejected 11476. Wrote 0 records.
# Processing COM00080259-data.txt.
#  Read 2065 headers, 256843 lines. Filtered 0. Rejected 2065. Wrote 0 records.
# Processing DRM00078486-data.txt.
#  Read 28418 headers, 1950589 lines. Filtered 15335. Rejected 11317. Wrote 1766 records.
# Processing FGM00081405-data.txt.
#  Read 31977 headers, 1764721 lines. Filtered 8474. Rejected 23503. Wrote 0 records.
# Processing GLM00004220-data.txt.
#  Read 50110 headers, 2837835 lines. Filtered 24372. Rejected 25738. Wrote 0 records.
# Processing GLM00004270-data.txt.
#  Read 58819 headers, 2869491 lines. Filtered 32901. Rejected 25918. Wrote 0 records.
# Processing GLM00004360-data.txt.
#  Read 48538 headers, 2304657 lines. Filtered 24136. Rejected 24402. Wrote 0 records.
# Processing GLM00004417-data.txt.
#  Read 7690 headers, 434464 lines. Filtered 0. Rejected 7690. Wrote 0 records.
# Processing GPM00078897-data.txt.
#  Read 43922 headers, 1725829 lines. Filtered 22251. Rejected 21671. Wrote 0 records.
# Processing JMM00078397-data.txt.
#  Read 39284 headers, 2180131 lines. Filtered 22895. Rejected 15370. Wrote 1019 records.
# Processing MXM00076256-data.txt.
#  Read 29369 headers, 1764096 lines. Filtered 17803. Rejected 11566. Wrote 0 records.
# Processing MXM00076394-data.txt.
#  Read 28559 headers, 1813687 lines. Filtered 17136. Rejected 11423. Wrote 0 records.
# Processing MXM00076405-data.txt.
#  Read 15907 headers, 1286036 lines. Filtered 3655. Rejected 12252. Wrote 0 records.
# Processing MXM00076458-data.txt.
#  Read 36750 headers, 2504216 lines. Filtered 20795. Rejected 15955. Wrote 0 records.
# Processing MXM00076526-data.txt.
#  Read 9507 headers, 1138172 lines. Filtered 0. Rejected 9507. Wrote 0 records.
# Processing MXM00076595-data.txt.
#  Read 9937 headers, 1177092 lines. Filtered 0. Rejected 9937. Wrote 0 records.
# Processing MXM00076612-data.txt.
#  Read 16452 headers, 1487680 lines. Filtered 3609. Rejected 12843. Wrote 0 records.
# Processing MXM00076644-data.txt.
#  Read 41594 headers, 2368386 lines. Filtered 26997. Rejected 14597. Wrote 0 records.
# Processing MXM00076654-data.txt.
#  Read 20686 headers, 1925236 lines. Filtered 4587. Rejected 16099. Wrote 0 records.
# Processing MXM00076679-data.txt.
#  Read 46704 headers, 3031094 lines. Filtered 22081. Rejected 24623. Wrote 0 records.
# Processing MXM00076692-data.txt.
#  Read 34574 headers, 2181367 lines. Filtered 18668. Rejected 15906. Wrote 0 records.
# Processing MXM00076743-data.txt.
#  Read 6450 headers, 871711 lines. Filtered 0. Rejected 6450. Wrote 0 records.
# Processing MXM00076805-data.txt.
#  Read 10996 headers, 1219983 lines. Filtered 120. Rejected 10876. Wrote 0 records.
# Processing MXM00076903-data.txt.
#  Read 2651 headers, 327324 lines. Filtered 0. Rejected 2651. Wrote 0 records.
# Processing NNM00078866-data.txt.
#  Read 27126 headers, 1576274 lines. Filtered 14922. Rejected 10847. Wrote 1357 records.
# Processing PMM00078807-data.txt.
#  Read 45686 headers, 1862467 lines. Filtered 32756. Rejected 12930. Wrote 0 records.
# Processing RQM00078526-data.txt.
#  Read 56922 headers, 5831285 lines. Filtered 30693. Rejected 3354. Wrote 22875 records.
# Processing TDM00078970-data.txt.
#  Read 27276 headers, 2168606 lines. Filtered 12431. Rejected 12044. Wrote 2801 records.
# Processing UCM00078988-data.txt.
#  Read 37500 headers, 2012248 lines. Filtered 23546. Rejected 9503. Wrote 4451 records.
# Processing USM00070026-data.txt.
#  Read 65231 headers, 5330226 lines. Filtered 35970. Rejected 7329. Wrote 21932 records.
# Processing USM00070133-data.txt.
#  Read 59747 headers, 5241942 lines. Filtered 35462. Rejected 5149. Wrote 19136 records.
# Processing USM00070200-data.txt.
#  Read 67948 headers, 5511347 lines. Filtered 42491. Rejected 5461. Wrote 19996 records.
# Processing USM00070219-data.txt.
#  Read 62998 headers, 5607006 lines. Filtered 37717. Rejected 5029. Wrote 20252 records.
# Processing USM00070231-data.txt.
#  Read 62656 headers, 5485808 lines. Filtered 37630. Rejected 5496. Wrote 19530 records.
# Processing USM00070261-data.txt.
#  Read 71022 headers, 5709511 lines. Filtered 44935. Rejected 6779. Wrote 19308 records.
# Processing USM00070273-data.txt.
#  Read 67312 headers, 5711603 lines. Filtered 41080. Rejected 5123. Wrote 21109 records.
# Processing USM00070308-data.txt.
#  Read 55782 headers, 5398659 lines. Filtered 30907. Rejected 5410. Wrote 19465 records.
# Processing USM00070316-data.txt.
#  Read 55261 headers, 5350590 lines. Filtered 29742. Rejected 5308. Wrote 20211 records.
# Processing USM00070326-data.txt.
#  Read 50989 headers, 5473310 lines. Filtered 25468. Rejected 4966. Wrote 20555 records.
# Processing USM00070350-data.txt.
#  Read 57772 headers, 5350582 lines. Filtered 31849. Rejected 6562. Wrote 19361 records.
# Processing USM00070361-data.txt.
#  Read 56393 headers, 5458740 lines. Filtered 30740. Rejected 5872. Wrote 19781 records.
# Processing USM00070398-data.txt.
#  Read 57264 headers, 5269584 lines. Filtered 31614. Rejected 6616. Wrote 19034 records.
# Processing USM00072201-data.txt.
#  Read 68770 headers, 5718633 lines. Filtered 42423. Rejected 3373. Wrote 22974 records.
# Processing USM00072202-data.txt.
#  Read 48099 headers, 4931575 lines. Filtered 25750. Rejected 1468. Wrote 20881 records.
# Processing USM00072206-data.txt.
#  Read 58315 headers, 4757482 lines. Filtered 35471. Rejected 2185. Wrote 20659 records.
# Processing USM00072208-data.txt.
#  Read 76704 headers, 5587894 lines. Filtered 50439. Rejected 7344. Wrote 18921 records.
# Processing USM00072210-data.txt.
#  Read 75229 headers, 5876894 lines. Filtered 48645. Rejected 5494. Wrote 21090 records.
# Processing USM00072215-data.txt.
#  Read 23054 headers, 4282883 lines. Filtered 0. Rejected 3183. Wrote 19871 records.
# Processing USM00072221-data.txt.
#  Read 54507 headers, 1777810 lines. Filtered 44625. Rejected 9882. Wrote 0 records.
# Processing USM00072230-data.txt.
#  Read 23224 headers, 4334657 lines. Filtered 0. Rejected 3270. Wrote 19954 records.
# Processing USM00072233-data.txt.
#  Read 28071 headers, 4993482 lines. Filtered 1127. Rejected 4491. Wrote 22453 records.
# Processing USM00072235-data.txt.
#  Read 66365 headers, 5657705 lines. Filtered 39443. Rejected 5016. Wrote 21906 records.
# Processing USM00072240-data.txt.
#  Read 67729 headers, 5828378 lines. Filtered 41214. Rejected 4903. Wrote 21612 records.
# Processing USM00072248-data.txt.
#  Read 44861 headers, 4815127 lines. Filtered 22010. Rejected 3323. Wrote 19528 records.
# Processing USM00072249-data.txt.
#  Read 50909 headers, 4737531 lines. Filtered 27471. Rejected 1600. Wrote 21838 records.
# Processing USM00072250-data.txt.
#  Read 78580 headers, 5759477 lines. Filtered 52329. Rejected 5160. Wrote 21091 records.
# Processing USM00072251-data.txt.
#  Read 35512 headers, 5007828 lines. Filtered 9037. Rejected 5484. Wrote 20991 records.
# Processing USM00072261-data.txt.
#  Read 54774 headers, 5410571 lines. Filtered 28757. Rejected 5896. Wrote 20121 records.
# Processing USM00072265-data.txt.
#  Read 63936 headers, 5382956 lines. Filtered 37682. Rejected 7408. Wrote 18846 records.
# Processing USM00072274-data.txt.
#  Read 68983 headers, 5307143 lines. Filtered 42820. Rejected 6588. Wrote 19575 records.
# Processing USM00072293-data.txt.
#  Read 57807 headers, 5259518 lines. Filtered 31679. Rejected 7176. Wrote 18952 records.
# Processing USM00072305-data.txt.
#  Read 23249 headers, 4335129 lines. Filtered 0. Rejected 3045. Wrote 20204 records.
# Processing USM00072317-data.txt.
#  Read 78525 headers, 5542212 lines. Filtered 52173. Rejected 5842. Wrote 20510 records.
# Processing USM00072318-data.txt.
#  Read 22010 headers, 4194102 lines. Filtered 0. Rejected 2696. Wrote 19314 records.
# Processing USM00072327-data.txt.
#  Read 71361 headers, 5551735 lines. Filtered 44796. Rejected 5772. Wrote 20793 records.
# Processing USM00072340-data.txt.
#  Read 57053 headers, 5542517 lines. Filtered 30446. Rejected 6982. Wrote 19625 records.
# Processing USM00072357-data.txt.
#  Read 27575 headers, 4371655 lines. Filtered 1283. Rejected 6329. Wrote 19963 records.
# Processing USM00072363-data.txt.
#  Read 78108 headers, 5394511 lines. Filtered 51762. Rejected 7613. Wrote 18733 records.
# Processing USM00072364-data.txt.
#  Read 76969 headers, 5403556 lines. Filtered 50870. Rejected 7956. Wrote 18143 records.
# Processing USM00072365-data.txt.
#  Read 85348 headers, 5190360 lines. Filtered 59168. Rejected 9116. Wrote 17064 records.
# Processing USM00072376-data.txt.
#  Read 21954 headers, 3857811 lines. Filtered 0. Rejected 5524. Wrote 16430 records.
# Processing USM00072381-data.txt.
#  Read 21812 headers, 953939 lines. Filtered 12726. Rejected 7470. Wrote 1616 records.
# Processing USM00072388-data.txt.
#  Read 41804 headers, 2501687 lines. Filtered 30982. Rejected 1901. Wrote 8921 records.
# Processing USM00072391-data.txt.
#  Read 17483 headers, 793366 lines. Filtered 12921. Rejected 3778. Wrote 784 records.
# Processing USM00072393-data.txt.
#  Read 46747 headers, 3373403 lines. Filtered 26555. Rejected 20192. Wrote 0 records.
# Processing USM00072402-data.txt.
#  Read 45849 headers, 4770313 lines. Filtered 19650. Rejected 15981. Wrote 10218 records.
# Processing USM00072403-data.txt.
#  Read 47996 headers, 5572760 lines. Filtered 21610. Rejected 4516. Wrote 21870 records.
# Processing USM00072426-data.txt.
#  Read 22958 headers, 4123366 lines. Filtered 813. Rejected 2938. Wrote 19207 records.
# Processing USM00072440-data.txt.
#  Read 33986 headers, 4363593 lines. Filtered 11262. Rejected 3192. Wrote 19532 records.
# Processing USM00072451-data.txt.
#  Read 66855 headers, 5124222 lines. Filtered 40504. Rejected 6339. Wrote 20012 records.
# Processing USM00072456-data.txt.
#  Read 55472 headers, 5422176 lines. Filtered 29081. Rejected 5543. Wrote 20848 records.
# Processing USM00072476-data.txt.
#  Read 70156 headers, 5199227 lines. Filtered 44485. Rejected 7861. Wrote 17810 records.
# Processing USM00072489-data.txt.
#  Read 48947 headers, 4193389 lines. Filtered 26282. Rejected 4869. Wrote 17796 records.
# Processing USM00072493-data.txt.
#  Read 79469 headers, 5537142 lines. Filtered 53405. Rejected 6775. Wrote 19289 records.
# Processing USM00072501-data.txt.
#  Read 22559 headers, 4174949 lines. Filtered 0. Rejected 2210. Wrote 20349 records.
# Processing USM00072518-data.txt.
#  Read 73909 headers, 5175864 lines. Filtered 48729. Rejected 8547. Wrote 16633 records.
# Processing USM00072520-data.txt.
#  Read 60269 headers, 5277989 lines. Filtered 34184. Rejected 4754. Wrote 21331 records.
# Processing USM00072528-data.txt.
#  Read 79875 headers, 5417021 lines. Filtered 53733. Rejected 5428. Wrote 20714 records.
# Processing USM00072558-data.txt.
#  Read 84756 headers, 5545662 lines. Filtered 58532. Rejected 6218. Wrote 20006 records.
# Processing USM00072562-data.txt.
#  Read 77468 headers, 5447033 lines. Filtered 51398. Rejected 6653. Wrote 19417 records.
# Processing USM00072572-data.txt.
#  Read 85969 headers, 5366343 lines. Filtered 59807. Rejected 7193. Wrote 18969 records.
# Processing USM00072582-data.txt.
#  Read 33300 headers, 4005035 lines. Filtered 11235. Rejected 5365. Wrote 16700 records.
# Processing USM00072597-data.txt.
#  Read 81267 headers, 5543305 lines. Filtered 55020. Rejected 7137. Wrote 19110 records.
# Processing USM00072632-data.txt.
#  Read 22569 headers, 4180664 lines. Filtered 0. Rejected 1630. Wrote 20939 records.
# Processing USM00072634-data.txt.
#  Read 21527 headers, 4085021 lines. Filtered 0. Rejected 2613. Wrote 18914 records.
# Processing USM00072645-data.txt.
#  Read 63185 headers, 5289872 lines. Filtered 37178. Rejected 5782. Wrote 20225 records.
# Processing USM00072649-data.txt.
#  Read 28130 headers, 4133846 lines. Filtered 5951. Rejected 2828. Wrote 19351 records.
# Processing USM00072659-data.txt.
#  Read 22598 headers, 4145048 lines. Filtered 0. Rejected 2362. Wrote 20236 records.
# Processing USM00072662-data.txt.
#  Read 70545 headers, 5356710 lines. Filtered 44407. Rejected 6192. Wrote 19946 records.
# Processing USM00072672-data.txt.
#  Read 21858 headers, 3846305 lines. Filtered 0. Rejected 5101. Wrote 16757 records.
# Processing USM00072681-data.txt.
#  Read 75263 headers, 5452210 lines. Filtered 49045. Rejected 7741. Wrote 18477 records.
# Processing USM00072694-data.txt.
#  Read 51847 headers, 5344360 lines. Filtered 25705. Rejected 7590. Wrote 18552 records.
# Processing USM00072712-data.txt.
#  Read 66304 headers, 5309296 lines. Filtered 40068. Rejected 5449. Wrote 20787 records.
# Processing USM00072747-data.txt.
#  Read 62689 headers, 5283897 lines. Filtered 36844. Rejected 5874. Wrote 19971 records.
# Processing USM00072764-data.txt.
#  Read 80495 headers, 5524320 lines. Filtered 54240. Rejected 6848. Wrote 19407 records.
# Processing USM00072768-data.txt.
#  Read 63443 headers, 5436609 lines. Filtered 37201. Rejected 7504. Wrote 18738 records.
# Processing USM00072776-data.txt.
#  Read 66985 headers, 5236859 lines. Filtered 40895. Rejected 6859. Wrote 19231 records.
# Processing USM00072786-data.txt.
#  Read 72791 headers, 5510877 lines. Filtered 46636. Rejected 8049. Wrote 18106 records.
# Processing USM00072797-data.txt.
#  Read 42893 headers, 5057388 lines. Filtered 16995. Rejected 7088. Wrote 18810 records.
# Processing USM00074003-data.txt.
#  Read 2143 headers, 55387 lines. Filtered 1680. Rejected 463. Wrote 0 records.
# Processing USM00074004-data.txt.
#  Read 14010 headers, 967805 lines. Filtered 0. Rejected 14010. Wrote 0 records.
# Processing USM00074005-data.txt.
#  Read 6719 headers, 468824 lines. Filtered 0. Rejected 6719. Wrote 0 records.
# Processing USM00074389-data.txt.
#  Read 65952 headers, 5607708 lines. Filtered 39761. Rejected 5220. Wrote 20971 records.
# Processing USM00074455-data.txt.
#  Read 24614 headers, 4320985 lines. Filtered 2104. Rejected 3032. Wrote 19478 records.
# Processing USM00074560-data.txt.
#  Read 22781 headers, 4253432 lines. Filtered 0. Rejected 3535. Wrote 19246 records.
# Processing USM00074612-data.txt.
#  Read 12763 headers, 342899 lines. Filtered 9718. Rejected 2006. Wrote 1039 records.
# Processing USM00074626-data.txt.
#  Read 5591 headers, 327423 lines. Filtered 0. Rejected 5591. Wrote 0 records.
# Processing USM00074646-data.txt.
#  Read 26489 headers, 2488583 lines. Filtered 0. Rejected 26489. Wrote 0 records.
# Processing USM00074794-data.txt.
#  Read 61012 headers, 4305844 lines. Filtered 32131. Rejected 28881. Wrote 0 records.
# Processing USM00091165-data.txt.
#  Read 68199 headers, 5696456 lines. Filtered 39183. Rejected 8323. Wrote 20693 records.
# Processing USM00091285-data.txt.
#  Read 65441 headers, 5679699 lines. Filtered 37127. Rejected 7445. Wrote 20869 records.
